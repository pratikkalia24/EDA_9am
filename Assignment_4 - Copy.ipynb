# %%
import random
dir(random)
random.randint(1,10)
# Out:
# 10

# %%
import random
dir(random)
random.random
help(random.random)
random.random()
# Out:
# Help on built-in function random:
#
# random() method of random.Random instance
#     random() -> x in the interval [0, 1).
# 0.6882547668923013

# %%
import random
dir(random)
l=[10,20,30,40]
random.choice(l)
# Out:
# 10

# %%
import random
dir(random)
a=[1,2,3,4]
random.sample(a,4)
# Out:
# [2, 4, 3, 1]

# %%
import random
random.seed(7)
random.randint(1,10) # if we want a random integer value
# Out:
# 6

# %%
import math
dir(math)
math.sqrt(16)
# Out:
# 4.0

# %%
import math
dir(math)
math.pow(2,8)
# Out:
# 256.0

# %%
import math
dir(math)
math.pi
# Out:
# 3.141592653589793

# %%
import math
dir(math)
math.e
# Out:
# 2.718281828459045

# %%
import time
dir(time)
start=time.time()  
time.sleep(5)
print('hello')
end=time.time()   
end-start
# Out:
# hello
# 5.0013017654418945

# %%
import time
dir(time) 
time.time()
# Out:
# 1763621860.8428404

# %%
import keyword
dir(keyword)
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import os
dir(os)
os.getcwd()
# Out:
# 'C:\\Users\\prati\\OneDrive\\Documents\\NareshIT\\Python_Sessions'

# %%
import os
dir(os)
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Assignment_3.ipynb',
#  'Assignment_4.ipynb',
#  'Session2.ipynb',
#  'Sessions1.ipynb',
#  'Sessions3.ipynb',
#  'Sessions_4.ipynb',
#  'Sessions_5.ipynb',
#  'Sessions_5_printstatement.ipynb',
#  'Session_1_variables.ipynb',
#  'Session_6_Pakages.ipynb',
#  'Untitled.ipynb',
#  'virat']

# %%
import datetime
dir(datetime)
today = datetime.date.today()
today
# Out:
# datetime.date(2025, 11, 20)
